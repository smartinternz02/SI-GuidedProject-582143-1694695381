# %%
#Assignment 1 (Name - Deepesh, Registration Number - 21BCE3055)

# %%
#Task 1 - Create a pandas dataframe (DataFrame name as 'df') (10 observation and 5 features)

import pandas as pd

df = pd.DataFrame([['Trek Dual Sport 3', 750, 30, 21, 'No'],
                   ['Giant Escape 3', 650, 28, 20, 'No'],
                   ['Cannondale Quick 6', 600, 27, 22, 'No'],
                   ['Specialized Allez', 800, 25, 23, 'No'],
                   ['Fuji Absolute 1.9', 700, 29, 22, 'No'],
                   ['Trek Marlin 5', 550, 32, 20, 'Yes'],
                   ['Giant Talon 2', 500, 30, 19, 'No'],
                   ['Cannondale Trail 7', 600, 28, 21, 'Yes'],
                   ['Specialized Rockhopper', 700, 26, 22, 'Yes'],
                   ['Fuji Nevada 1.7', 650, 29, 21, 'Yes']])

df.columns = ['Model','Price($)','Weight(lbs)','Speed(mph)','Rear Shock']
df.index = ['Bike 1','Bike 2','Bike 3','Bike 4','Bike 5','Bike 6','Bike 7','Bike 8','Bike 9','Bike 10']

df
# Out:
#                           Model  Price($)  Weight(lbs)  Speed(mph) Rear Shock
# Bike 1        Trek Dual Sport 3       750           30          21         No
# Bike 2           Giant Escape 3       650           28          20         No
# Bike 3       Cannondale Quick 6       600           27          22         No
# Bike 4        Specialized Allez       800           25          23         No
# Bike 5        Fuji Absolute 1.9       700           29          22         No
# Bike 6            Trek Marlin 5       550           32          20        Yes
# Bike 7            Giant Talon 2       500           30          19         No
# Bike 8       Cannondale Trail 7       600           28          21        Yes
# Bike 9   Specialized Rockhopper       700           26          22        Yes
# Bike 10         Fuji Nevada 1.7       650           29          21        Yes

# %%
#Task 2 - Check the info of 'df'

df_info = df.info()
df_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Bike 1 to Bike 10
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Model        10 non-null     object
#  1   Price($)     10 non-null     int64
#  2   Weight(lbs)  10 non-null     int64
#  3   Speed(mph)   10 non-null     int64
#  4   Rear Shock   10 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 480.0+ bytes

# %%
#Task 3 - Check the descriptive statistics of 'df'

descriptive_statistics = df.describe()
descriptive_statistics
# Out:
#          Price($)  Weight(lbs)  Speed(mph)
# count   10.000000    10.000000   10.000000
# mean   650.000000    28.400000   21.100000
# std     91.287093     2.065591    1.197219
# min    500.000000    25.000000   19.000000
# 25%    600.000000    27.250000   20.250000
# 50%    650.000000    28.500000   21.000000
# 75%    700.000000    29.750000   22.000000
# max    800.000000    32.000000   23.000000

# %%
#Task 4 - Check the 4th index observation with 'loc' slicing operator

Index4_Observation = df.loc['Bike 4']
Index4_Observation
# Out:
# Model          Specialized Allez
# Price($)                     800
# Weight(lbs)                   25
# Speed(mph)                    23
# Rear Shock                    No
# Name: Bike 4, dtype: object

# %%
#Task 5 - Check the null values in your 'df'

df_null = df.isnull().any()
df_null
# Out:
# Model          False
# Price($)       False
# Weight(lbs)    False
# Speed(mph)     False
# Rear Shock     False
# dtype: bool

# %%
#Another way for task 5

# %%
#Task 5 - Check the null values in your 'df'

df_null1 = df.isnull() #We can check null values with this syntax also
df_null1
# Out:
#          Model  Price($)  Weight(lbs)  Speed(mph)  Rear Shock
# Bike 1   False     False        False       False       False
# Bike 2   False     False        False       False       False
# Bike 3   False     False        False       False       False
# Bike 4   False     False        False       False       False
# Bike 5   False     False        False       False       False
# Bike 6   False     False        False       False       False
# Bike 7   False     False        False       False       False
# Bike 8   False     False        False       False       False
# Bike 9   False     False        False       False       False
# Bike 10  False     False        False       False       False
